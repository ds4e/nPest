# %%
import pandas as pd
import matplotlib as plt
import numpy as np

from nPest.np import ecdf, kde

df = pd.read_csv('./nPest/data/heart_failure_clinical_records_dataset.csv')
x = df['age']

# %% [markdown]
# ## Make an ECDF

# %%
model = ecdf(x)
model.plot()

# %% [markdown]
# ## Compute Sample Proportion/ECDF Value from Fitted ECDF

# %%
model.prop(56)
# Out:
# np.float64(0.3779264214046823)

# %% [markdown]
# ## Compute Quantile from Fitted ECDF

# %%
model.quantile(.7)
# Out:
# np.float64(65.0)

# %% [markdown]
# ## Make a KDE

# %%
model = kde(x, kernel_type='uniform')
model.fit()
model.plot()
print( f'Bandwidth is: {model.h:.2f}' )
# Out:
# Bandwidth is: 6.99

# %%
model = kde(x, kernel_type='gaussian')
model.fit()
model.plot()
print( f'Bandwidth is: {model.h:.2f}' )
# Out:
# Bandwidth is: 4.03

# %% [markdown]
# ## Overlay Plots in a Loop

# %%
for i in range(3):
    df_i = df.sample( frac = 1.0, replace = True )
    model = kde( df_i['age'])
    model.fit()
    model.plot()

# %%
for i in range(3):
    df_i = df.sample( frac = 1.0, replace = True )
    model = ecdf( df_i['age'])
    model.plot()

# %% [markdown]
# ## Vary the Bandwidth

# %%
h_grid = np.linspace(2,12,4)

for h in h_grid:
    df_i = df.sample( frac = 1.0, replace = True )
    model = kde( df_i['age'], kernel_type='gaussian' )
    model.fit(h=h)
    model.plot()

# %%
h_grid = np.linspace(2, 12, 4)

for h in h_grid:
    df_i = df.sample( frac = 1.0, replace = True )
    model = kde( df_i['age'], kernel_type='uniform' )
    model.fit(h=h)
    model.plot()

# %% [markdown]
# ## Vary the Kernel

# %%
h_grid = np.linspace(2,12,10)

for type in ['uniform', 'gaussian']:
    df_i = df.sample( frac = 1.0, replace = True )
    model = kde( df_i['age'], kernel_type= type)
    model.fit()
    model.plot()
